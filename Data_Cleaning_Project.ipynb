# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/gurpreetsingh/Documents/Bepec/Assignment Folders'

# %%
os.chdir('/Users/gurpreetsingh/Documents/Bepec/Assignment Folders')

# %%
lending_data=pd.read_excel('Lending Data.xlsx')

# %%
lending_data.head(30)
# Out:
#                Name of Lending Institution HQ State Rank  TA Ratio1  \
# 0                                      NaN      NaN   -1         -2
# 1                    American Express Co.       NY     1    0.23829
# 2                 First Citizens Banchares      NC     2   0.187393
# 3                 Wintrust Financial Corp.      IL     3   0.168999
# 4                            Zions Bancorp      UT     4   0.117973
# 5                  Synovus Financial Corp.      GA     5   0.162333
# 6                              BB&T Corp.       NC     6  0.0534601
# 7                               FNB Corp.       PA     7   0.127672
# 8              Capital One Financial Corp.      VA     8  0.0275597
# 9                  Fulton Financial Corp.       PA     8   0.129126
# 10                 Regions Financial Corp.      AL    10  0.0610388
# 11                            U S Bancorp.      MN    11   0.042109
# 12           First Niagara Financial Grp.       NY    11  0.0721729
# ...

# %%
lending_data.dtypes
# Out:
# Name of Lending Institution     object
# HQ State                        object
# Rank                            object
# TA Ratio1                       object
# TBL Ratio1                      object
# Amount ($1,000)                 object
# Number                          object
# Lender Asset Size               object
# Amount ($1,000).1              float64
# Number .1                      float64
# Unnamed: 10                    float64
# Amount ($1,000).2              float64
# Number .2                      float64
# CC Amount/TA1                   object
# dtype: object

# %%
lending_data.drop([94,95,96], axis=0)
# Out:
#           Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                                 NaN      NaN   -1        -2         -3
# 1               American Express Co.       NY     1   0.23829   0.999544
# 2            First Citizens Banchares      NC     2  0.187393    0.49083
# 3            Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4                       Zions Bancorp      UT     4  0.117973   0.260577
# ..                                ...      ...  ...       ...        ...
# 89  USAA Svg. Bank                          NV   NR         0          -
# 90                State Street Corp.       MA    NR         -          -
# 91     E Trade Bk                           VA   NR         -          -
# 92     Charles Schwab Bk                    NV   NR         -          -
# 93     Third FS&LA                          OH   NR         -          -
#
#    Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# ...

# %%
lending_data.drop('Unnamed: 10', inplace = True, axis=1)

# %%
lending_data.drop(0)
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 1                               American Express Co.       NY     1   0.23829
# 2                            First Citizens Banchares      NC     2  0.187393
# 3                            Wintrust Financial Corp.      IL     3  0.168999
# 4                                       Zions Bancorp      UT     4  0.117973
# 5                             Synovus Financial Corp.      GA     5  0.162333
# ..                                                ...      ...  ...       ...
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
# ...

# %%
lending_data.fillna(lending_data.mean(), inplace=True)
lending_data.head(30)
# Out:
#                Name of Lending Institution HQ State Rank  TA Ratio1  \
# 0                                      NaN      NaN   -1         -2
# 1                    American Express Co.       NY     1    0.23829
# 2                 First Citizens Banchares      NC     2   0.187393
# 3                 Wintrust Financial Corp.      IL     3   0.168999
# 4                            Zions Bancorp      UT     4   0.117973
# 5                  Synovus Financial Corp.      GA     5   0.162333
# 6                              BB&T Corp.       NC     6  0.0534601
# 7                               FNB Corp.       PA     7   0.127672
# 8              Capital One Financial Corp.      VA     8  0.0275597
# 9                  Fulton Financial Corp.       PA     8   0.129126
# 10                 Regions Financial Corp.      AL    10  0.0610388
# 11                            U S Bancorp.      MN    11   0.042109
# 12           First Niagara Financial Grp.       NY    11  0.0721729
# ...

# %%
lending_data['Rank'].fillna('89')
lending_data.tail(10)
# Out:
#                           Name of Lending Institution HQ State Rank  \
# 87                           Goldman Sachs Group The       NY    87
# 88                           Deutsche Bk Tc Americas       NY    88
# 89                  USAA Svg. Bank                          NV   NR
# 90                                State Street Corp.       MA    NR
# 91                     E Trade Bk                           VA   NR
# 92                     Charles Schwab Bk                    NV   NR
# 93                     Third FS&LA                          OH   NR
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN
#
#       TA Ratio1   TBL Ratio1 Amount ($1,000) Number      Lender Asset Size  \
# 87  3.48757e-05   0.00102276            4000       6  >$50B
# 88  4.67874e-05  0.000333249            2000       4  $10B-$50B
# ...

# %%
lending_data.drop([94,95,96], axis=0)
# Out:
#           Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                                 NaN      NaN   -1        -2         -3
# 1               American Express Co.       NY     1   0.23829   0.999544
# 2            First Citizens Banchares      NC     2  0.187393    0.49083
# 3            Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4                       Zions Bancorp      UT     4  0.117973   0.260577
# ..                                ...      ...  ...       ...        ...
# 89  USAA Svg. Bank                          NV   NR         0          -
# 90                State Street Corp.       MA    NR         -          -
# 91     E Trade Bk                           VA   NR         -          -
# 92     Charles Schwab Bk                    NV   NR         -          -
# 93     Third FS&LA                          OH   NR         -          -
#
#    Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# ...

# %%
lending_data.describe()
# Out:
#        Amount ($1,000).1     Number .1  Amount ($1,000).2      Number .2
# count       9.700000e+01  9.700000e+01       9.700000e+01      97.000000
# mean        9.919647e+05  1.964819e+05       2.023422e+06    8425.255319
# std         2.774209e+06  6.535318e+05       3.621651e+06   14772.112041
# min        -7.000000e+00 -8.000000e+00      -9.000000e+00     -10.000000
# 25%         2.052300e+04  7.220000e+02       1.936390e+05     565.000000
# 50%         1.468920e+05  8.562000e+03       9.165160e+05    4094.000000
# 75%         5.929670e+05  3.740500e+04       2.188715e+06   10534.000000
# max         1.631809e+07  3.603088e+06       2.615439e+07  107411.000000

# %%
lending_data.mean()
# Out:
# Amount ($1,000).1    9.919647e+05
# Number .1            1.964819e+05
# Amount ($1,000).2    2.023422e+06
# Number .2            8.425255e+03
# dtype: float64

# %%
lending_data['TA Ratio1'].map(lending_data.mean())
lending_data.tail(10)
# Out:
#                           Name of Lending Institution HQ State Rank  \
# 87                           Goldman Sachs Group The       NY    87
# 88                           Deutsche Bk Tc Americas       NY    88
# 89                  USAA Svg. Bank                          NV   NR
# 90                                State Street Corp.       MA    NR
# 91                     E Trade Bk                           VA   NR
# 92                     Charles Schwab Bk                    NV   NR
# 93                     Third FS&LA                          OH   NR
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN
#
#       TA Ratio1   TBL Ratio1 Amount ($1,000) Number      Lender Asset Size  \
# 87  3.48757e-05   0.00102276            4000       6  >$50B
# 88  4.67874e-05  0.000333249            2000       4  $10B-$50B
# ...

# %%
lending_data['TA Ratio1']
# Out:
# 0           -2
# 1      0.23829
# 2     0.187393
# 3     0.168999
# 4     0.117973
#         ...
# 92           -
# 93           -
# 94         NaN
# 95         NaN
# 96         NaN
# Name: TA Ratio1, Length: 97, dtype: object

# %%
lending_data['TA Ratio1'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 92    False
# 93    False
# 94     True
# 95     True
# 96     True
# Name: TA Ratio1, Length: 97, dtype: bool

# %%
missing_values=['-','.','NR']
lending_data=pd.read_excel('Lending Data.xlsx',na_values= missing_values)
lending_data['TA Ratio1']
# Out:
# 0    -2.000000
# 1     0.238290
# 2     0.187393
# 3     0.168999
# 4     0.117973
#         ...
# 92         NaN
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# Name: TA Ratio1, Length: 97, dtype: float64

# %%
lending_data['TA Ratio1'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 92     True
# 93     True
# 94     True
# 95     True
# 96     True
# Name: TA Ratio1, Length: 97, dtype: bool

# %%
lending_data['TA Ratio1'].drop(index=94,axis=0)
# Out:
# 0    -2.000000
# 1     0.238290
# 2     0.187393
# 3     0.168999
# 4     0.117973
#         ...
# 91         NaN
# 92         NaN
# 93         NaN
# 95         NaN
# 96         NaN
# Name: TA Ratio1, Length: 96, dtype: float64

# %%
lending_data.isnull().sum
# Out:
# <bound method DataFrame.sum of     Name of Lending Institution  HQ State   Rank  TA Ratio1  TBL Ratio1  \
# 0                          True      True  False      False       False
# 1                         False     False  False      False       False
# 2                         False     False  False      False       False
# 3                         False     False  False      False       False
# 4                         False     False  False      False       False
# ..                          ...       ...    ...        ...         ...
# 92                        False     False   True       True        True
# 93                        False     False   True       True        True
# 94                        False      True   True       True        True
# 95                        False      True   True       True        True
# 96                        False      True   True       True        True
#
# ...

# %%
lending_data.isnull().sum().sum()
# Out:
# 157

# %%
mean=lending_data['TA Ratio1'].mean()

# %%
mean
# Out:
# 0.025905005971433418

# %%
lending_data['TA Ratio1'].mean()
# Out:
# 0.025905005971433418

# %%
lending_data['TBL Ratio1'].mean()
# Out:
# 0.21466617047275557

# %%
lending_data['Amount ($1,000)'].mean()
# Out:
# 3149404.4777777777

# %%
lending_data['TA Ratio1'].fillna(mean, inplace=True)

# %%
lending_data.tail(10)
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 87                           Goldman Sachs Group The       NY   87.0
# 88                           Deutsche Bk Tc Americas       NY   88.0
# 89                  USAA Svg. Bank                          NV   NaN
# 90                                State Street Corp.       MA    NaN
# 91                     E Trade Bk                           VA   NaN
# 92                     Charles Schwab Bk                    NV   NaN
# 93                     Third FS&LA                          OH   NaN
# 94  *The bank was formerly known as GE Money Bank,...      NaN   NaN
# 95  1 TA = total domestic assets held by the lende...      NaN   NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN   NaN
#
#     TA Ratio1  TBL Ratio1  Amount ($1,000)  Number      Lender Asset Size  \
# 87   0.000035    0.001023           4000.0      6.0  >$50B
# 88   0.000047    0.000333           2000.0      4.0  $10B-$50B
# ...

# %%
lending_data['TBL Ratio1'].fillna(mean, inplace=True)
lending_data.tail(10)
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 87                           Goldman Sachs Group The       NY   87.0
# 88                           Deutsche Bk Tc Americas       NY   88.0
# 89                  USAA Svg. Bank                          NV   NaN
# 90                                State Street Corp.       MA    NaN
# 91                     E Trade Bk                           VA   NaN
# 92                     Charles Schwab Bk                    NV   NaN
# 93                     Third FS&LA                          OH   NaN
# 94  *The bank was formerly known as GE Money Bank,...      NaN   NaN
# 95  1 TA = total domestic assets held by the lende...      NaN   NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN   NaN
#
#     TA Ratio1  TBL Ratio1  Amount ($1,000)  Number      Lender Asset Size  \
# 87   0.000035    0.001023           4000.0      6.0  >$50B
# 88   0.000047    0.000333           2000.0      4.0  $10B-$50B
# ...

# %%
lending_data['Amount ($1,000)'].fillna(mean, inplace=True)
lending_data.tail(10)
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 87                           Goldman Sachs Group The       NY   87.0
# 88                           Deutsche Bk Tc Americas       NY   88.0
# 89                  USAA Svg. Bank                          NV   NaN
# 90                                State Street Corp.       MA    NaN
# 91                     E Trade Bk                           VA   NaN
# 92                     Charles Schwab Bk                    NV   NaN
# 93                     Third FS&LA                          OH   NaN
# 94  *The bank was formerly known as GE Money Bank,...      NaN   NaN
# 95  1 TA = total domestic assets held by the lende...      NaN   NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN   NaN
#
#     TA Ratio1  TBL Ratio1  Amount ($1,000)  Number      Lender Asset Size  \
# 87   0.000035    0.001023      4000.000000      6.0  >$50B
# 88   0.000047    0.000333      2000.000000      4.0  $10B-$50B
# ...

# %%
lending_data['Rank'].fillna(method='ffill', inplace=True)
lending_data.tail(10)
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 87                           Goldman Sachs Group The       NY   87.0
# 88                           Deutsche Bk Tc Americas       NY   88.0
# 89                  USAA Svg. Bank                          NV  88.0
# 90                                State Street Corp.       MA   88.0
# 91                     E Trade Bk                           VA  88.0
# 92                     Charles Schwab Bk                    NV  88.0
# 93                     Third FS&LA                          OH  88.0
# 94  *The bank was formerly known as GE Money Bank,...      NaN  88.0
# 95  1 TA = total domestic assets held by the lende...      NaN  88.0
# 96  Source: U.S. Small Business Administration, Of...      NaN  88.0
#
#     TA Ratio1  TBL Ratio1  Amount ($1,000)  Number      Lender Asset Size  \
# 87   0.000035    0.001023      4000.000000      6.0  >$50B
# 88   0.000047    0.000333      2000.000000      4.0  $10B-$50B
# ...

# %%
lending_data.drop([94,95,96], axis=0)
# Out:
#           Name of Lending Institution HQ State  Rank  TA Ratio1  TBL Ratio1  \
# 0                                 NaN      NaN  -1.0  -2.000000   -3.000000
# 1               American Express Co.       NY    1.0   0.238290    0.999544
# 2            First Citizens Banchares      NC    2.0   0.187393    0.490830
# 3            Wintrust Financial Corp.      IL    3.0   0.168999    0.383561
# 4                       Zions Bancorp      UT    4.0   0.117973    0.260577
# ..                                ...      ...   ...        ...         ...
# 89  USAA Svg. Bank                          NV  88.0   0.000000    0.025905
# 90                State Street Corp.       MA   88.0   0.025905    0.025905
# 91     E Trade Bk                           VA  88.0   0.025905    0.025905
# 92     Charles Schwab Bk                    NV  88.0   0.025905    0.025905
# 93     Third FS&LA                          OH  88.0   0.025905    0.025905
#
# ...

# %%
lending_data.drop('Unnamed: 10', inplace = True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-339-0575e7bce0a6> in <module>
# ----> 1 lending_data.drop('Unnamed: 10', inplace = True, axis=1)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...
